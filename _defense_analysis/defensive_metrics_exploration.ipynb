# %% [markdown]
# This notebook is for understanding the structure of the data returned by the API, exploring the contents, and identifying key fields and their relevance

# %%
# Dependencies
import requests
import json

# %%
# API Endpoint
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'

# %%
# Send a GET request to the API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # Pretty print the JSON data to understand the structure
    print(json.dumps(data, indent=4))
 
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {
#     "events": [
#         {
#             "id": 1,
#             "name": "Gameweek 1",
#             "deadline_time": "2024-08-16T17:30:00Z",
#             "release_time": null,
#             "average_entry_score": 57,
#             "finished": true,
#             "data_checked": true,
#             "highest_scoring_entry": 3546234,
#             "deadline_time_epoch": 1723829400,
#             "deadline_time_game_offset": 0,
#             "highest_score": 127,
#             "is_previous": true,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 8597356,
#             "chip_plays": [
#                 {
#                     "chip_name": "bboost",
#                     "num_played": 144974
#                 },
#                 {
#                     "chip_name": "3xc",
#                     "num_played": 221430
#                 }
#             ],
#             "most_selected": 401,
#             "most_transferred_in": 1,
#             "top_element": 328,
#             "top_element_info": {
#                 "id": 328,
#                 "points": 14
#             },
#             "transfers_made": 0,
#             "most_captained": 351,
#             "most_vice_captained": 351
#         },
#         {
#             "id": 2,
#             "name": "Gameweek 2",
#             "deadline_time": "2024-08-24T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 69,
#             "finished": true,
#             "data_checked": true,
#             "highest_scoring_entry": 9442126,
#             "deadline_time_epoch": 1724493600,
#             "deadline_time_game_offset": 0,
#             "highest_score": 154,
#             "is_previous": false,
#             "is_current": true,
#             "is_next": false,
#             "cup_leagues_created": true,
#             "h2h_ko_matches_created": true,
#             "ranked_count": 9543353,
#             "chip_plays": [
#                 {
#                     "chip_name": "bboost",
#                     "num_played": 118782
#                 },
#                 {
#                     "chip_name": "freehit",
#                     "num_played": 102788
#                 },
#                 {
#                     "chip_name": "wildcard",
#                     "num_played": 217521
#                 },
#                 {
#                     "chip_name": "3xc",
#                     "num_played": 612384
#                 }
#             ],
#             "most_selected": 401,
#             "most_transferred_in": 594,
#             "top_element": 177,
#             "top_element_info": {
#                 "id": 177,
#                 "points": 20
#             },
#             "transfers_made": 13364453,
#             "most_captained": 351,
#             "most_vice_captained": 401
#         },
#         {
#             "id": 3,
#             "name": "Gameweek 3",
#             "deadline_time": "2024-08-31T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1725098400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": true,
#             "cup_leagues_created": true,
#             "h2h_ko_matches_created": true,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 4,
#             "name": "Gameweek 4",
#             "deadline_time": "2024-09-14T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1726308000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 5,
#             "name": "Gameweek 5",
#             "deadline_time": "2024-09-21T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1726912800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 6,
#             "name": "Gameweek 6",
#             "deadline_time": "2024-09-28T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1727517600,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 7,
#             "name": "Gameweek 7",
#             "deadline_time": "2024-10-05T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1728122400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 8,
#             "name": "Gameweek 8",
#             "deadline_time": "2024-10-19T10:00:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1729332000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 9,
#             "name": "Gameweek 9",
#             "deadline_time": "2024-10-25T17:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1729877400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 10,
#             "name": "Gameweek 10",
#             "deadline_time": "2024-11-02T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1730554200,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 11,
#             "name": "Gameweek 11",
#             "deadline_time": "2024-11-09T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1731159000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 12,
#             "name": "Gameweek 12",
#             "deadline_time": "2024-11-23T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1732368600,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 13,
#             "name": "Gameweek 13",
#             "deadline_time": "2024-11-30T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1732973400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 14,
#             "name": "Gameweek 14",
#             "deadline_time": "2024-12-03T18:15:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1733249700,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 15,
#             "name": "Gameweek 15",
#             "deadline_time": "2024-12-07T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1733578200,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 16,
#             "name": "Gameweek 16",
#             "deadline_time": "2024-12-14T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1734183000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 17,
#             "name": "Gameweek 17",
#             "deadline_time": "2024-12-21T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1734787800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 18,
#             "name": "Gameweek 18",
#             "deadline_time": "2024-12-26T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1735219800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 19,
#             "name": "Gameweek 19",
#             "deadline_time": "2024-12-29T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1735479000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 20,
#             "name": "Gameweek 20",
#             "deadline_time": "2025-01-04T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1735997400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 21,
#             "name": "Gameweek 21",
#             "deadline_time": "2025-01-14T18:15:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1736878500,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 22,
#             "name": "Gameweek 22",
#             "deadline_time": "2025-01-18T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1737207000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 23,
#             "name": "Gameweek 23",
#             "deadline_time": "2025-01-25T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1737811800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 24,
#             "name": "Gameweek 24",
#             "deadline_time": "2025-02-01T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1738416600,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 25,
#             "name": "Gameweek 25",
#             "deadline_time": "2025-02-15T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1739626200,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 26,
#             "name": "Gameweek 26",
#             "deadline_time": "2025-02-22T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1740231000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 27,
#             "name": "Gameweek 27",
#             "deadline_time": "2025-02-25T18:15:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1740507300,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 28,
#             "name": "Gameweek 28",
#             "deadline_time": "2025-03-08T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1741440600,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 29,
#             "name": "Gameweek 29",
#             "deadline_time": "2025-03-15T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1742045400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 30,
#             "name": "Gameweek 30",
#             "deadline_time": "2025-04-01T17:15:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1743527700,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 31,
#             "name": "Gameweek 31",
#             "deadline_time": "2025-04-05T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1743856200,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 32,
#             "name": "Gameweek 32",
#             "deadline_time": "2025-04-12T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1744461000,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 33,
#             "name": "Gameweek 33",
#             "deadline_time": "2025-04-19T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1745065800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 34,
#             "name": "Gameweek 34",
#             "deadline_time": "2025-04-26T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1745670600,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 35,
#             "name": "Gameweek 35",
#             "deadline_time": "2025-05-03T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1746275400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 36,
#             "name": "Gameweek 36",
#             "deadline_time": "2025-05-10T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1746880200,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 37,
#             "name": "Gameweek 37",
#             "deadline_time": "2025-05-18T12:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1747571400,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         },
#         {
#             "id": 38,
#             "name": "Gameweek 38",
#             "deadline_time": "2025-05-25T13:30:00Z",
#             "release_time": null,
#             "average_entry_score": 0,
#             "finished": false,
#             "data_checked": false,
#             "highest_scoring_entry": null,
#             "deadline_time_epoch": 1748179800,
#             "deadline_time_game_offset": 0,
#             "highest_score": null,
#             "is_previous": false,
#             "is_current": false,
#             "is_next": false,
#             "cup_leagues_created": false,
#             "h2h_ko_matches_created": false,
#             "ranked_count": 0,
#             "chip_plays": [],
#             "most_selected": null,
#             "most_transferred_in": null,
#             "top_element": null,
#             "top_element_info": null,
#             "transfers_made": 0,
#             "most_captained": null,
#             "most_vice_captained": null
#         }
#     ],
#     "game_settings": {
#         "league_join_private_max": 30,
#         "league_join_public_max": 5,
#         "league_max_size_public_classic": 20,
#         "league_max_size_public_h2h": 16,
#         "league_max_size_private_h2h": 16,
#         "league_max_ko_rounds_private_h2h": 3,
#         "league_prefix_public": "League",
#         "league_points_h2h_win": 3,
#         "league_points_h2h_lose": 0,
#         "league_points_h2h_draw": 1,
#         "league_ko_first_instead_of_random": false,
#         "cup_start_event_id": null,
#         "cup_stop_event_id": null,
#         "cup_qualifying_method": null,
#         "cup_type": null,
#         "featured_entries": [],
#         "percentile_ranks": [
#             1,
#             5,
#             10,
#             15,
#             20,
#             25,
#             30,
#             35,
#             40,
#             45,
#             50,
#             55,
#             60,
#             65,
#             70,
#             75,
#             80,
#             95,
#             90,
#             95
#         ],
#         "squad_squadplay": 11,
#         "squad_squadsize": 15,
#         "squad_team_limit": 3,
#         "squad_total_spend": 1000,
#         "ui_currency_multiplier": 10,
#         "ui_use_special_shirts": false,
#         "ui_special_shirt_exclusions": [],
#         "stats_form_days": 30,
#         "sys_vice_captain_enabled": true,
#         "transfers_cap": 20,
#         "transfers_sell_on_fee": 0.5,
#         "max_extra_free_transfers": 4,
#         "league_h2h_tiebreak_stats": [
#             "+goals_scored",
#             "-goals_conceded"
#         ],
#         "timezone": "UTC"
#     },
#     "phases": [
#         {
#             "id": 1,
#             "name": "Overall",
#             "start_event": 1,
#             "stop_event": 38,
#             "highest_score": 235
#         },
#         {
#             "id": 2,
#             "name": "August",
#             "start_event": 1,
#             "stop_event": 3,
#             "highest_score": 235
#         },
#         {
#             "id": 3,
#             "name": "September",
#             "start_event": 4,
#             "stop_event": 6,
#             "highest_score": null
#         },
#         {
#             "id": 4,
#             "name": "October",
#             "start_event": 7,
#             "stop_event": 9,
#             "highest_score": null
#         },
#         {
#             "id": 5,
#             "name": "November",
#             "start_event": 10,
#             "stop_event": 13,
#             "highest_score": null
#         },
#         {
#             "id": 6,
#             "name": "December",
#             "start_event": 14,
#             "stop_event": 19,
#             "highest_score": null
#         },
#         {
#             "id": 7,
#             "name": "January",
#             "start_event": 20,
#             "stop_event": 23,
#             "highest_score": null
#         },
#         {
#             "id": 8,
#             "name": "February",
#             "start_event": 24,
#             "stop_event": 27,
#             "highest_score": null
#         },
#         {
#             "id": 9,
#             "name": "March",
#             "start_event": 28,
#             "stop_event": 29,
#             "highest_score": null
#         },
#         {
#             "id": 10,
#             "name": "April",
#             "start_event": 30,
#             "stop_event": 34,
#             "highest_score": null
#         },
#         {
#             "id": 11,
#             "name": "May",
#             "start_event": 35,
#             "stop_event": 38,
#             "highest_score": null
#         }
#     ],
#     "teams": [
#         {
#             "code": 3,
#             "draw": 0,
#             "form": null,
#             "id": 1,
#             "loss": 0,
#             "name": "Arsenal",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "ARS",
#             "strength": 5,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1350,
#             "strength_overall_away": 1380,
#             "strength_attack_home": 1370,
#             "strength_attack_away": 1370,
#             "strength_defence_home": 1330,
#             "strength_defence_away": 1390,
#             "pulse_id": 1
#         },
#         {
#             "code": 7,
#             "draw": 0,
#             "form": null,
#             "id": 2,
#             "loss": 0,
#             "name": "Aston Villa",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "AVL",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1120,
#             "strength_overall_away": 1245,
#             "strength_attack_home": 1110,
#             "strength_attack_away": 1140,
#             "strength_defence_home": 1130,
#             "strength_defence_away": 1350,
#             "pulse_id": 2
#         },
#         {
#             "code": 91,
#             "draw": 0,
#             "form": null,
#             "id": 3,
#             "loss": 0,
#             "name": "Bournemouth",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "BOU",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1100,
#             "strength_overall_away": 1100,
#             "strength_attack_home": 1075,
#             "strength_attack_away": 1100,
#             "strength_defence_home": 1130,
#             "strength_defence_away": 1105,
#             "pulse_id": 127
#         },
#         {
#             "code": 94,
#             "draw": 0,
#             "form": null,
#             "id": 4,
#             "loss": 0,
#             "name": "Brentford",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "BRE",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1100,
#             "strength_overall_away": 1100,
#             "strength_attack_home": 1105,
#             "strength_attack_away": 1095,
#             "strength_defence_home": 1100,
#             "strength_defence_away": 1110,
#             "pulse_id": 130
#         },
#         {
#             "code": 36,
#             "draw": 0,
#             "form": null,
#             "id": 5,
#             "loss": 0,
#             "name": "Brighton",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "BHA",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1100,
#             "strength_overall_away": 1100,
#             "strength_attack_home": 1100,
#             "strength_attack_away": 1105,
#             "strength_defence_home": 1100,
#             "strength_defence_away": 1100,
#             "pulse_id": 131
#         },
#         {
#             "code": 8,
#             "draw": 0,
#             "form": null,
#             "id": 6,
#             "loss": 0,
#             "name": "Chelsea",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "CHE",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1130,
#             "strength_overall_away": 1255,
#             "strength_attack_home": 1090,
#             "strength_attack_away": 1180,
#             "strength_defence_home": 1170,
#             "strength_defence_away": 1330,
#             "pulse_id": 4
#         },
#         {
#             "code": 31,
#             "draw": 0,
#             "form": null,
#             "id": 7,
#             "loss": 0,
#             "name": "Crystal Palace",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "CRY",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1100,
#             "strength_overall_away": 1165,
#             "strength_attack_home": 1110,
#             "strength_attack_away": 1180,
#             "strength_defence_home": 1090,
#             "strength_defence_away": 1155,
#             "pulse_id": 6
#         },
#         {
#             "code": 11,
#             "draw": 0,
#             "form": null,
#             "id": 8,
#             "loss": 0,
#             "name": "Everton",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "EVE",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1090,
#             "strength_overall_away": 1125,
#             "strength_attack_home": 1100,
#             "strength_attack_away": 1175,
#             "strength_defence_home": 1080,
#             "strength_defence_away": 1080,
#             "pulse_id": 7
#         },
#         {
#             "code": 54,
#             "draw": 0,
#             "form": null,
#             "id": 9,
#             "loss": 0,
#             "name": "Fulham",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "FUL",
#             "strength": 3,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1080,
#             "strength_overall_away": 1125,
#             "strength_attack_home": 1070,
#             "strength_attack_away": 1130,
#             "strength_defence_home": 1090,
#             "strength_defence_away": 1120,
#             "pulse_id": 34
#         },
#         {
#             "code": 40,
#             "draw": 0,
#             "form": null,
#             "id": 10,
#             "loss": 0,
#             "name": "Ipswich",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "IPS",
#             "strength": 2,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1050,
#             "strength_overall_away": 1050,
#             "strength_attack_home": 1050,
#             "strength_attack_away": 1050,
#             "strength_defence_home": 1050,
#             "strength_defence_away": 1050,
#             "pulse_id": 8
#         },
#         {
#             "code": 13,
#             "draw": 0,
#             "form": null,
#             "id": 11,
#             "loss": 0,
#             "name": "Leicester",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "LEI",
#             "strength": 2,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1050,
#             "strength_overall_away": 1060,
#             "strength_attack_home": 1060,
#             "strength_attack_away": 1050,
#             "strength_defence_home": 1060,
#             "strength_defence_away": 1050,
#             "pulse_id": 26
#         },
#         {
#             "code": 14,
#             "draw": 0,
#             "form": null,
#             "id": 12,
#             "loss": 0,
#             "name": "Liverpool",
#             "played": 0,
#             "points": 0,
#             "position": 0,
#             "short_name": "LIV",
#             "strength": 4,
#             "team_division": null,
#             "unavailable": false,
#             "win": 0,
#             "strength_overall_home": 1235,
#             "strength_overall_away": 1370,
# ...
#             "points_per_game": "0.0",
#             "second_name": "Bueno",
#             "selected_by_percent": "0.1",
#             "special": false,
#             "squad_number": null,
#             "status": "a",
#             "team": 20,
#             "team_code": 39,
#             "total_points": 0,
#             "transfers_in": 220,
#             "transfers_in_event": 106,
#             "transfers_out": 1698,
#             "transfers_out_event": 663,
#             "value_form": "0.0",
#             "value_season": "0.0",
#             "web_name": "S.Bueno",
#             "minutes": 0,
#             "goals_scored": 0,
#             "assists": 0,
#             "clean_sheets": 0,
#             "goals_conceded": 0,
#             "own_goals": 0,
#             "penalties_saved": 0,
#             "penalties_missed": 0,
#             "yellow_cards": 0,
#             "red_cards": 0,
#             "saves": 0,
#             "bonus": 0,
#             "bps": 0,
#             "influence": "0.0",
#             "creativity": "0.0",
#             "threat": "0.0",
#             "ict_index": "0.0",
#             "starts": 0,
#             "expected_goals": "0.00",
#             "expected_assists": "0.00",
#             "expected_goal_involvements": "0.00",
#             "expected_goals_conceded": "0.00",
#             "influence_rank": 454,
#             "influence_rank_type": 185,
#             "creativity_rank": 452,
#             "creativity_rank_type": 184,
#             "threat_rank": 409,
#             "threat_rank_type": 168,
#             "ict_index_rank": 462,
#             "ict_index_rank_type": 185,
#             "corners_and_indirect_freekicks_order": null,
#             "corners_and_indirect_freekicks_text": "",
#             "direct_freekicks_order": null,
#             "direct_freekicks_text": "",
#             "penalties_order": null,
#             "penalties_text": "",
#             "expected_goals_per_90": 0,
#             "saves_per_90": 0,
#             "expected_assists_per_90": 0,
#             "expected_goal_involvements_per_90": 0,
#             "expected_goals_conceded_per_90": 0,
#             "goals_conceded_per_90": 0,
#             "now_cost_rank": 414,
#             "now_cost_rank_type": 97,
#             "form_rank": 461,
#             "form_rank_type": 182,
#             "points_per_game_rank": 461,
#             "points_per_game_rank_type": 182,
#             "selected_rank": 466,
#             "selected_rank_type": 170,
#             "starts_per_90": 0,
#             "clean_sheets_per_90": 0
#         },
#         {
#             "chance_of_playing_next_round": null,
#             "chance_of_playing_this_round": null,
#             "code": 88484,
#             "cost_change_event": -1,
#             "cost_change_event_fall": 1,
#             "cost_change_start": -1,
#             "cost_change_start_fall": 1,
#             "dreamteam_count": 0,
#             "element_type": 3,
#             "ep_next": "1.0",
#             "ep_this": "1.0",
#             "event_points": 1,
#             "first_name": "Pablo",
#             "form": "1.0",
#             "id": 565,
#             "in_dreamteam": false,
#             "news": "",
#             "news_added": null,
#             "now_cost": 54,
#             "photo": "88484.jpg",
#             "points_per_game": "1.0",
#             "second_name": "Sarabia",
#             "selected_by_percent": "0.2",
#             "special": false,
#             "squad_number": null,
#             "status": "a",
#             "team": 20,
#             "team_code": 39,
#             "total_points": 2,
#             "transfers_in": 1304,
#             "transfers_in_event": 672,
#             "transfers_out": 6962,
#             "transfers_out_event": 3234,
#             "value_form": "0.2",
#             "value_season": "0.4",
#             "web_name": "Sarabia",
#             "minutes": 28,
#             "goals_scored": 0,
#             "assists": 0,
#             "clean_sheets": 0,
#             "goals_conceded": 1,
#             "own_goals": 0,
#             "penalties_saved": 0,
#             "penalties_missed": 0,
#             "yellow_cards": 0,
#             "red_cards": 0,
#             "saves": 0,
#             "bonus": 0,
#             "bps": 13,
#             "influence": "15.8",
#             "creativity": "3.2",
#             "threat": "36.0",
#             "ict_index": "5.5",
#             "starts": 0,
#             "expected_goals": "0.10",
#             "expected_assists": "0.02",
#             "expected_goal_involvements": "0.12",
#             "expected_goals_conceded": "0.32",
#             "influence_rank": 200,
#             "influence_rank_type": 84,
#             "creativity_rank": 222,
#             "creativity_rank_type": 133,
#             "threat_rank": 49,
#             "threat_rank_type": 30,
#             "ict_index_rank": 134,
#             "ict_index_rank_type": 79,
#             "corners_and_indirect_freekicks_order": 1,
#             "corners_and_indirect_freekicks_text": "",
#             "direct_freekicks_order": 2,
#             "direct_freekicks_text": "",
#             "penalties_order": 2,
#             "penalties_text": "",
#             "expected_goals_per_90": 0.32,
#             "saves_per_90": 0.0,
#             "expected_assists_per_90": 0.06,
#             "expected_goal_involvements_per_90": 0.38,
#             "expected_goals_conceded_per_90": 1.03,
#             "goals_conceded_per_90": 3.21,
#             "now_cost_rank": 151,
#             "now_cost_rank_type": 93,
#             "form_rank": 251,
#             "form_rank_type": 129,
#             "points_per_game_rank": 288,
#             "points_per_game_rank_type": 149,
#             "selected_rank": 370,
#             "selected_rank_type": 126,
#             "starts_per_90": 0.0,
#             "clean_sheets_per_90": 0.0
#         },
#         {
#             "chance_of_playing_next_round": null,
#             "chance_of_playing_this_round": null,
#             "code": 247412,
#             "cost_change_event": 0,
#             "cost_change_event_fall": 0,
#             "cost_change_start": 0,
#             "cost_change_start_fall": 0,
#             "dreamteam_count": 0,
#             "element_type": 4,
#             "ep_next": "4.0",
#             "ep_this": "4.0",
#             "event_points": 6,
#             "first_name": "J\u00f8rgen",
#             "form": "4.0",
#             "id": 566,
#             "in_dreamteam": false,
#             "news": "",
#             "news_added": null,
#             "now_cost": 55,
#             "photo": "247412.jpg",
#             "points_per_game": "4.0",
#             "second_name": "Strand Larsen",
#             "selected_by_percent": "0.7",
#             "special": false,
#             "squad_number": null,
#             "status": "a",
#             "team": 20,
#             "team_code": 39,
#             "total_points": 8,
#             "transfers_in": 53392,
#             "transfers_in_event": 48527,
#             "transfers_out": 13772,
#             "transfers_out_event": 11685,
#             "value_form": "0.7",
#             "value_season": "1.5",
#             "web_name": "Strand Larsen",
#             "minutes": 173,
#             "goals_scored": 1,
#             "assists": 0,
#             "clean_sheets": 0,
#             "goals_conceded": 8,
#             "own_goals": 0,
#             "penalties_saved": 0,
#             "penalties_missed": 0,
#             "yellow_cards": 0,
#             "red_cards": 0,
#             "saves": 0,
#             "bonus": 0,
#             "bps": 37,
#             "influence": "46.6",
#             "creativity": "13.7",
#             "threat": "48.0",
#             "ict_index": "10.8",
#             "starts": 2,
#             "expected_goals": "0.66",
#             "expected_assists": "0.16",
#             "expected_goal_involvements": "0.82",
#             "expected_goals_conceded": "2.80",
#             "influence_rank": 48,
#             "influence_rank_type": 8,
#             "creativity_rank": 147,
#             "creativity_rank_type": 15,
#             "threat_rank": 30,
#             "threat_rank_type": 12,
#             "ict_index_rank": 58,
#             "ict_index_rank_type": 11,
#             "corners_and_indirect_freekicks_order": null,
#             "corners_and_indirect_freekicks_text": "",
#             "direct_freekicks_order": null,
#             "direct_freekicks_text": "",
#             "penalties_order": null,
#             "penalties_text": "",
#             "expected_goals_per_90": 0.34,
#             "saves_per_90": 0.0,
#             "expected_assists_per_90": 0.08,
#             "expected_goal_involvements_per_90": 0.42,
#             "expected_goals_conceded_per_90": 1.46,
#             "goals_conceded_per_90": 4.16,
#             "now_cost_rank": 125,
#             "now_cost_rank_type": 35,
#             "form_rank": 78,
#             "form_rank_type": 10,
#             "points_per_game_rank": 81,
#             "points_per_game_rank_type": 10,
#             "selected_rank": 220,
#             "selected_rank_type": 36,
#             "starts_per_90": 1.04,
#             "clean_sheets_per_90": 0.0
#         },
#         {
#             "chance_of_playing_next_round": null,
#             "chance_of_playing_this_round": null,
#             "code": 510362,
#             "cost_change_event": 0,
#             "cost_change_event_fall": 0,
#             "cost_change_start": 0,
#             "cost_change_start_fall": 0,
#             "dreamteam_count": 0,
#             "element_type": 2,
#             "ep_next": "1.0",
#             "ep_this": "1.0",
#             "event_points": 2,
#             "first_name": "Toti Ant\u00f3nio",
#             "form": "1.0",
#             "id": 567,
#             "in_dreamteam": false,
#             "news": "",
#             "news_added": null,
#             "now_cost": 45,
#             "photo": "510362.jpg",
#             "points_per_game": "1.0",
#             "second_name": "Gomes",
#             "selected_by_percent": "0.2",
#             "special": false,
#             "squad_number": null,
#             "status": "a",
#             "team": 20,
#             "team_code": 39,
#             "total_points": 2,
#             "transfers_in": 1240,
#             "transfers_in_event": 813,
#             "transfers_out": 4586,
#             "transfers_out_event": 1533,
#             "value_form": "0.2",
#             "value_season": "0.4",
#             "web_name": "Toti",
#             "minutes": 180,
#             "goals_scored": 0,
#             "assists": 1,
#             "clean_sheets": 0,
#             "goals_conceded": 8,
#             "own_goals": 0,
#             "penalties_saved": 0,
#             "penalties_missed": 0,
#             "yellow_cards": 1,
#             "red_cards": 0,
#             "saves": 0,
#             "bonus": 0,
#             "bps": -3,
#             "influence": "35.0",
#             "creativity": "11.7",
#             "threat": "8.0",
#             "ict_index": "5.5",
#             "starts": 2,
#             "expected_goals": "0.00",
#             "expected_assists": "0.23",
#             "expected_goal_involvements": "0.23",
#             "expected_goals_conceded": "2.80",
#             "influence_rank": 97,
#             "influence_rank_type": 31,
#             "creativity_rank": 164,
#             "creativity_rank_type": 41,
#             "threat_rank": 148,
#             "threat_rank_type": 30,
#             "ict_index_rank": 131,
#             "ict_index_rank_type": 33,
#             "corners_and_indirect_freekicks_order": null,
#             "corners_and_indirect_freekicks_text": "",
#             "direct_freekicks_order": null,
#             "direct_freekicks_text": "",
#             "penalties_order": null,
#             "penalties_text": "",
#             "expected_goals_per_90": 0.0,
#             "saves_per_90": 0.0,
#             "expected_assists_per_90": 0.12,
#             "expected_goal_involvements_per_90": 0.12,
#             "expected_goals_conceded_per_90": 1.4,
#             "goals_conceded_per_90": 4.0,
#             "now_cost_rank": 489,
#             "now_cost_rank_type": 127,
#             "form_rank": 225,
#             "form_rank_type": 72,
#             "points_per_game_rank": 241,
#             "points_per_game_rank_type": 83,
#             "selected_rank": 344,
#             "selected_rank_type": 124,
#             "starts_per_90": 1.0,
#             "clean_sheets_per_90": 0.0
#         }
#     ],
#     "element_stats": [
#         {
#             "label": "Minutes played",
#             "name": "minutes"
#         },
#         {
#             "label": "Goals scored",
#             "name": "goals_scored"
#         },
#         {
#             "label": "Assists",
#             "name": "assists"
#         },
#         {
#             "label": "Clean sheets",
#             "name": "clean_sheets"
#         },
#         {
#             "label": "Goals conceded",
#             "name": "goals_conceded"
#         },
#         {
#             "label": "Own goals",
#             "name": "own_goals"
#         },
#         {
#             "label": "Penalties saved",
#             "name": "penalties_saved"
#         },
#         {
#             "label": "Penalties missed",
#             "name": "penalties_missed"
#         },
#         {
#             "label": "Yellow cards",
#             "name": "yellow_cards"
#         },
#         {
#             "label": "Red cards",
#             "name": "red_cards"
#         },
#         {
#             "label": "Saves",
#             "name": "saves"
#         },
#         {
#             "label": "Bonus",
#             "name": "bonus"
#         },
#         {
#             "label": "Bonus Points System",
#             "name": "bps"
#         },
#         {
#             "label": "Influence",
#             "name": "influence"
#         },
#         {
#             "label": "Creativity",
#             "name": "creativity"
#         },
#         {
#             "label": "Threat",
#             "name": "threat"
#         },
#         {
#             "label": "ICT Index",
#             "name": "ict_index"
#         },
#         {
#             "label": "Game(s) Started",
#             "name": "starts"
#         },
#         {
#             "label": "Expected Goals",
#             "name": "expected_goals"
#         },
#         {
#             "label": "Expected Assists",
#             "name": "expected_assists"
#         },
#         {
#             "label": "Expected Goal Involvements",
#             "name": "expected_goal_involvements"
#         },
#         {
#             "label": "Expected Goals Conceded",
#             "name": "expected_goals_conceded"
#         }
#     ],
#     "element_types": [
#         {
#             "id": 1,
#             "plural_name": "Goalkeepers",
#             "plural_name_short": "GKP",
#             "singular_name": "Goalkeeper",
#             "singular_name_short": "GKP",
#             "squad_select": 2,
#             "squad_min_select": null,
#             "squad_max_select": null,
#             "squad_min_play": 1,
#             "squad_max_play": 1,
#             "ui_shirt_specific": true,
#             "sub_positions_locked": [
#                 12
#             ],
#             "element_count": 67
#         },
#         {
#             "id": 2,
#             "plural_name": "Defenders",
#             "plural_name_short": "DEF",
#             "singular_name": "Defender",
#             "singular_name_short": "DEF",
#             "squad_select": 5,
#             "squad_min_select": null,
#             "squad_max_select": null,
#             "squad_min_play": 3,
#             "squad_max_play": 5,
#             "ui_shirt_specific": false,
#             "sub_positions_locked": [],
#             "element_count": 207
#         },
#         {
#             "id": 3,
#             "plural_name": "Midfielders",
#             "plural_name_short": "MID",
#             "singular_name": "Midfielder",
#             "singular_name_short": "MID",
#             "squad_select": 5,
#             "squad_min_select": null,
#             "squad_max_select": null,
#             "squad_min_play": 2,
#             "squad_max_play": 5,
#             "ui_shirt_specific": false,
#             "sub_positions_locked": [],
#             "element_count": 287
#         },
#         {
#             "id": 4,
#             "plural_name": "Forwards",
#             "plural_name_short": "FWD",
#             "singular_name": "Forward",
#             "singular_name_short": "FWD",
#             "squad_select": 3,
#             "squad_min_select": null,
#             "squad_max_select": null,
#             "squad_min_play": 1,
#             "squad_max_play": 3,
#             "ui_shirt_specific": false,
#             "sub_positions_locked": [],
#             "element_count": 72
#         }
#     ]
# }

# %% [markdown]
# ## Potential Defensive Metrics:
# 1. Tackles:
# * Total number of tackles made by a player.
# * Tackles won (successful tackles that retained possession for the team).
# 2. Interceptions:
# * Total interceptions made (number of times a player stops an opponent's pass by positioning themselves in the path of the ball).
# 3. Clearances:
# * The total number of clearances (kicking or heading the ball away from the goal area to prevent the opposition from scoring).
# 4. Blocks:
# * Shots blocked (number of times a player blocks an opponent's shot).
# * Passes blocked (number of times a player blocks a pass to prevent it from reaching its intended target).
# 5. Aerial Duels Won:
# * Number of times a player wins a contest for the ball in the air.
# 6. Recoveries:
# * Number of times a player regains possession of the ball after it has been lost by their team.
# 7. Fouls Committed and Cards Received:
# * Number of fouls committed by the player.
# * Number of yellow and red cards received (to measure discipline and risk of suspension).
# 8. Minutes Played:
# * Total minutes played (to normalize metrics per minute played, ensuring comparisons are fair across players with different playing times).
# 9. Clean Sheets:
# * Number of matches where the player's team did not concede any goals while the player was on the field.
# 10. Errors Leading to Goals:
# * Number of mistakes made by a player that directly resulted in the opponent scoring a goal.
# 11. Touches:
# * Number of touches a player has, which can indicate involvement in play and ability to influence the game defensively.
# 12. Successful Passes and Passing Accuracy:
# * Number of successful passes made by the player.
# * Passing accuracy percentage, which can indicate a player's ability to maintain possession and distribute effectively from the back.

# %% [markdown]
# ## API Response Analysis
# Based on the analysis of the API's JSON output, several key fields can represent defensive metrics or other relevant player statistics that are based on facts and are not engineered features by thge data provider.
# 1. clean_sheets: Indicates the number of matches in which the player's team did not concede any goals while the player was on the field. This is a crucial metric for defenders, as clean sheets are often a significant source of points in fantasy football.
# 2. goals_conceded: Shows the number of goals conceded while the player was on the field. Lower numbers can indicate strong defensive performance.
# 3. yellow_cards and red_cards: These fields show the number of yellow and red cards received by the player, respectively. This can be important for assessing discipline and risk, as frequent cards can lead to suspensions and point deductions.
# 4. minutes: The total number of minutes played by the player. This can be used to calculate per-minute defensive contributions and ensure the player is a regular starter.
# 5. bps (Bonus Points System): This system awards points for various actions like tackles, interceptions, and blocks. While bps is a composite score, it can be a valuable indicator of a player's all-around contribution.
# 6. starts: Number of games a player has started. Regular starters are usually more reliable choices for analysis.
# 7. own_goals: Number of own goals scored by the player. It's a negative metric for defenders, indicating costly mistakes.

# %% [markdown]
# ### To get all of the desired metrics, additional data sources may be required.
